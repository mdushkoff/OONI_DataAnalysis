# %% [markdown]
# # OONI Data Analysis - Preliminary Exploration

# %%
# Imports
from matplotlib import pyplot as plt
import seaborn
import pandas as pd
import numpy as np
import os
from urllib.parse import urlparse

# %%
# Plot configuration
seaborn.set_style('dark')

# %% [markdown]
# ## (1) Data Cleaning
# In this step we load and clean up the pre-procsesed data in order to get it into a form that can be analyzed.

# %%
# Load the pre-processed data and set up the index based on date
data_dir = '../results/HR/processed/2022/'
web_connectivity = pd.read_csv(os.path.join(data_dir, 'webconnectivity.csv'))
web_connectivity['date'] = pd.to_datetime(web_connectivity['date'])
web_connectivity = web_connectivity.set_index('date')
web_connectivity
# Out:
#            probe_asn resolver_asn  x_dns_flags  x_blocking_flags title_match  \
# date
# 2022-01-02    AS5391       AS5391          NaN               NaN        True
# 2022-01-02    AS5391       AS5391          NaN               NaN         NaN
# 2022-01-02    AS5391       AS5391          NaN               NaN        True
# 2022-01-02    AS5391       AS5391          NaN               NaN         NaN
# 2022-01-02    AS5391       AS5391          NaN               NaN        True
# ...              ...          ...          ...               ...         ...
# 2022-12-31   AS34594      AS34594          NaN               NaN        True
# 2022-12-31   AS34594      AS34594          NaN               NaN         NaN
# 2022-12-31   AS34594      AS34594          NaN               NaN         NaN
# 2022-12-31   AS34594      AS34594          NaN               NaN         NaN
# 2022-12-31   AS34594      AS34594          NaN               NaN         NaN
#
#            http_experiment_failure control_failure blocking headers_match  \
# date
# 2022-01-02                     NaN             NaN    False          True
# 2022-01-02                     NaN             NaN    False          True
# 2022-01-02                     NaN             NaN    False          True
# 2022-01-02                     NaN             NaN    False          True
# 2022-01-02                     NaN             NaN    False          True
# ...                            ...             ...      ...           ...
# 2022-12-31                     NaN             NaN    False          True
# 2022-12-31                     NaN             NaN    False          True
# 2022-12-31                     NaN             NaN    False         False
# 2022-12-31                     NaN             NaN    False          True
# 2022-12-31                     NaN             NaN    False          True
#
#            dns_consistency                                            input  \
# date
# 2022-01-02      consistent                         https://allo.google.com/
# 2022-01-02      consistent      https://app.developer.here.com/coronavirus/
# 2022-01-02      consistent  https://apps.crowdtangle.com/public-hub/covid19
# 2022-01-02      consistent                            https://app.wire.com/
# 2022-01-02      consistent                         https://archive.org/web/
# ...                    ...                                              ...
# 2022-12-31      consistent                         https://www.spotify.com/
# 2022-12-31      consistent                           https://www.state.gov/
# 2022-12-31      consistent                     https://www.state.gov/j/drl/
# 2022-12-31      consistent                       https://www.instagram.com/
# 2022-12-31      consistent                         https://www.youtube.com/
#
#            accessible body_length_match  body_proportion  x_null_null_flags  \
# date
# 2022-01-02       True              True         1.000000                NaN
# 2022-01-02       True              True         1.000000                NaN
# 2022-01-02       True              True         1.000000                NaN
# 2022-01-02       True               NaN         0.000000                NaN
# 2022-01-02       True              True         0.999836                NaN
# ...               ...               ...              ...                ...
# 2022-12-31       True              True         0.988822                NaN
# 2022-12-31       True               NaN         0.000000                NaN
# 2022-12-31       True               NaN         0.000000                NaN
# 2022-12-31       True               NaN         0.000000                NaN
# 2022-12-31       True               NaN         0.000000                NaN
#
#            status_code_match dns_experiment_failure
# date
# 2022-01-02              True                    NaN
# 2022-01-02              True                    NaN
# 2022-01-02              True                    NaN
# 2022-01-02              True                    NaN
# 2022-01-02              True                    NaN
# ...                      ...                    ...
# 2022-12-31              True                    NaN
# 2022-12-31              True                    NaN
# 2022-12-31              True                    NaN
# 2022-12-31             False                    NaN
# 2022-12-31              True                    NaN
#
# [365034 rows x 17 columns]

# %%
# Standardize URLs
def url_standardize(url):
    p = urlparse(url)
    b = p.netloc.split('.')
    c = '.'.join(b[len(b)-2:])  # Remove any www
    return c+p.path
    
web_connectivity['input'] = web_connectivity['input'].map(url_standardize)

# %%
# Filter data into specific blocking methods
dns_events = web_connectivity[web_connectivity['blocking'] == 'dns']
httpdiff_events = web_connectivity[web_connectivity['blocking'] == 'http-diff']
httpfail_events = web_connectivity[web_connectivity['blocking'] == 'http-failure']
tcp_events = web_connectivity[web_connectivity['blocking'] == 'tcp_ip']
web_connectivity['blocking'].unique()
# Out:
# array(['False', 'http-diff', nan, 'tcp_ip', 'dns', 'http-failure'],
#       dtype=object)

# %% [markdown]
# ## (2) Data Exploration

# %%
# Compute rolling totals
k=7
date_range = pd.date_range(start="2022-01-01", end="2022-12-31", freq='D')

temp_events = web_connectivity.groupby(web_connectivity.index).size()
total_events = temp_events.reindex(date_range, fill_value=0).rolling(window=k).sum().dropna()

temp_dns = dns_events.groupby(dns_events.index).size()
total_dns = temp_dns.reindex(date_range, fill_value=0).rolling(window=k).sum().dropna()

temp_httpdiff = httpdiff_events.groupby(httpdiff_events.index).size()
total_httpdiff = temp_httpdiff.reindex(date_range, fill_value=0).rolling(window=k).sum().dropna()

temp_httpfail = httpfail_events.groupby(httpfail_events.index).size()
total_httpfail = temp_httpfail.reindex(date_range, fill_value=0).rolling(window=k).sum().dropna()

temp_tcp = tcp_events.groupby(tcp_events.index).size()
total_tcp = temp_tcp.reindex(date_range, fill_value=0).rolling(window=k).sum().dropna()

# %%
# Compute fractional events
frac_dns = total_dns/total_events
frac_httpdiff = total_httpdiff/total_events
frac_httpfail = total_httpfail/total_events
frac_tcp = total_tcp/total_events
frac_dns = frac_dns.fillna(0)
frac_httpdiff = frac_httpdiff.fillna(0)
frac_httpfail = frac_httpfail.fillna(0)
frac_tcp = frac_tcp.fillna(0)

# %%
# Plot fractional events
plt.rcParams['figure.figsize'] = [20, 5]
plt.stackplot(total_events.index, frac_dns, frac_httpdiff, frac_httpfail, frac_tcp, labels=['dns', 'http-diff', 'http-failure', 'tcp'], alpha=0.65)
plt.legend()
plt.grid()
plt.title(f'Fractional Blocking Events Over Time (k={k})')
# Out:
# Text(0.5, 1.0, 'Fractional Blocking Events Over Time (k=7)')

# %%
# Zoom in on a region of interest
start_date = '2022-03-24'
end_date = '2022-04-18'
filter_range = total_events.index[(total_events.index >= start_date) & (total_events.index <= end_date)]
plt.rcParams['figure.figsize'] = [10, 5]
plt.stackplot(filter_range, frac_dns[filter_range], frac_httpdiff[filter_range], frac_httpfail[filter_range], frac_tcp[filter_range], labels=['dns', 'http-diff', 'http-failure', 'tcp'], alpha=0.65)
plt.legend()
plt.grid()
plt.title(f'Fractional Blocking Events From {start_date}-{end_date} (k={k})')
# Out:
# Text(0.5, 1.0, 'Fractional Blocking Events From 2022-03-24-2022-04-18 (k=7)')

# %%
# Get blocking events in small date range
filter_tcp_range = (tcp_events.index >= start_date) & (tcp_events.index <= end_date)
filter_total_range = (web_connectivity.index >= start_date) & (web_connectivity.index <= end_date)
tcp_during = tcp_events[filter_tcp_range].groupby('input').size()
total_during = web_connectivity[filter_total_range].groupby('input').size()
frac_tcp_during = (tcp_during/total_during).fillna(0)
tcp_during.sort_values(ascending=False)
tcp_out = tcp_events[~filter_tcp_range].groupby('input').size()
total_out = web_connectivity[~filter_total_range].groupby('input').size()
frac_tcp_out = (tcp_out/total_out).fillna(0)
diff_frac_tcp = (frac_tcp_during-frac_tcp_out).sort_values(ascending=False).dropna()
diff_frac_tcp[:30]
# Out:
# input
# i2p2.de/                               0.835766
# vanguardnewsnetwork.com/               0.563853
# usacasino.com/                         0.562882
# youporn.com/                           0.562254
# realbeer.com/                          0.523810
# rxmarijuana.com/                       0.523810
# thegooddrugsguide.com/                 0.515038
# topdrawers.com/                        0.514881
# datpiff.com/                           0.500000
# angryharry.com/                        0.500000
# tobacco.org/                           0.492366
# winespectator.com/                     0.490991
# xvideos.com/                           0.490741
# venus.com/                             0.482143
# monacogoldcasino.com/                  0.476190
# moderndrunkardmagazine.com/            0.476190
# spinpalace.com/                        0.476190
# pokerpages.com/                        0.476190
# poker.com/                             0.476190
# pof.com/                               0.476190
# royalvegas.com/                        0.476190
# riverbelle.com/                        0.476190
# rollitup.org/                          0.476190
# anonym.to/                             0.475000
# jmarshall.com/                         0.473666
# hackforums.net/                        0.465064
# idsoftware.com/                        0.464756
# msftconnecttest.com/connecttest.txt    0.464425
# globalvoicesonline.org/                0.460294
# creativecommons.org/                   0.459805
# dtype: float64

# %%
from statsmodels.stats.proportion import proportions_ztest

blocking_start = "2022-03-24"
blocking_end = "2022-04-18"

inner_range = (web_connectivity.index >= start_date) & (web_connectivity.index <= end_date)
outer_range = (web_connectivity.index < start_date) | (web_connectivity.index > end_date)
tcp_during = web_connectivity[inner_range].groupby('blocking').size()
tcp_outside = web_connectivity[outer_range].groupby('blocking').size()

successes = [tcp_during.sum() - tcp_during["False"], tcp_outside.sum() - tcp_outside["False"]]
sample_sizes = [tcp_during.sum(), tcp_outside.sum()]
print(successes)
print(sample_sizes)
z_stat, p_value = proportions_ztest(successes, sample_sizes)
print(f"Z-Statistic: {z_stat}")
print(f"P-Value: {p_value}")
print(successes[0] / sample_sizes[0])
print(successes[1] / sample_sizes[1])
# Out:
# [7615, 6687]
# [48022, 310089]
# Z-Statistic: 142.67971992795134
# P-Value: 0.0
# 0.1585731539710966
# 0.021564776564147712

# %%
import scipy.stats as stats

# Chi-square test of independence of variables
grouped_frame = pd.DataFrame({
    "during": tcp_during,
    "outside": tcp_outside
})
chi2, p_value, dof, expected = stats.chi2_contingency(grouped_frame.T)  # .T to transpose and get the correct format

# Step 3: Output the results
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p_value}")
# Out:
# Chi-square statistic: 29270.643280440243
# P-value: 0.0

# %%
tcp_blocked = tcp_events[filter_tcp_range].groupby('input').size()
print(len(tcp_blocked))
for i, j in tcp_during.items():
    print(str(i) + " " + str(j))
# Out:
# 698
# False 40407
# dns 406
# http-diff 234
# http-failure 142
# tcp_ip 6833

# %%
# Plot fractional events
plt.rcParams['figure.figsize'] = [20, 5]
plt.stackplot(total_events.index, frac_dns, frac_httpdiff, frac_httpfail, frac_tcp, labels=['dns', 'http-diff', 'http-failure', 'tcp'], alpha=0.65)
plt.legend()
plt.grid()
plt.title(f'Fractional Blocking Events Over Time (k={k})')
# Out:
# Text(0.5, 1.0, 'Fractional Blocking Events Over Time (k=7)')

# %%
# Extract known blocking methods
web_maybe_blocked = web_connectivity.loc[(web_connectivity['blocking'] != 'False') & (~web_connectivity['blocking'].isnull())]
web_maybe_blocked = web_maybe_blocked.sort_values(by=["input", "date"])
wmbi = web_maybe_blocked.set_index(['input', web_maybe_blocked.index])
wmbi
# Out:
#                                           probe_asn resolver_asn  x_dns_flags  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17    AS5391       AS5391          NaN
#                                2022-04-17    AS5391       AS5391          NaN
#                                2022-04-17    AS5391       AS5391          NaN
#                                2022-04-17    AS5391       AS5391          NaN
#                                2022-04-18    AS5391       AS5391          NaN
# ...                                             ...          ...          ...
# zzn.com/                       2022-04-08    AS5391      AS13335          NaN
#                                2022-04-22    AS5391      AS13335          NaN
#                                2022-04-22    AS5391      AS13335          NaN
#                                2022-05-10    AS5391      AS13335          NaN
#                                2022-08-11    AS5391       AS5391          NaN
#
#                                            x_blocking_flags title_match  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17               NaN         NaN
#                                2022-04-17               NaN         NaN
#                                2022-04-17               NaN         NaN
#                                2022-04-17               NaN         NaN
#                                2022-04-18               NaN         NaN
# ...                                                     ...         ...
# zzn.com/                       2022-04-08               NaN         NaN
#                                2022-04-22               NaN         NaN
#                                2022-04-22               NaN         NaN
#                                2022-05-10               NaN         NaN
#                                2022-08-11               NaN         NaN
#
#                                                                      http_experiment_failure  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17                              generic_timeout_error
#                                2022-04-17                              generic_timeout_error
#                                2022-04-17                              generic_timeout_error
#                                2022-04-17                              generic_timeout_error
#                                2022-04-18                              generic_timeout_error
# ...                                                                                      ...
# zzn.com/                       2022-04-08                              generic_timeout_error
#                                2022-04-22                              generic_timeout_error
#                                2022-04-22                              generic_timeout_error
#                                2022-05-10  unknown_failure: dial tcp [scrubbed]: connect:...
#                                2022-08-11                              generic_timeout_error
#
#                                           control_failure blocking  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17             NaN   tcp_ip
#                                2022-04-17             NaN   tcp_ip
#                                2022-04-17             NaN   tcp_ip
#                                2022-04-17             NaN   tcp_ip
#                                2022-04-18             NaN   tcp_ip
# ...                                                   ...      ...
# zzn.com/                       2022-04-08             NaN   tcp_ip
#                                2022-04-22             NaN   tcp_ip
#                                2022-04-22             NaN   tcp_ip
#                                2022-05-10             NaN   tcp_ip
#                                2022-08-11             NaN   tcp_ip
#
#                                           headers_match dns_consistency  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17           NaN      consistent
#                                2022-04-17           NaN      consistent
#                                2022-04-17           NaN      consistent
#                                2022-04-17           NaN      consistent
#                                2022-04-18           NaN      consistent
# ...                                                 ...             ...
# zzn.com/                       2022-04-08           NaN      consistent
#                                2022-04-22           NaN      consistent
#                                2022-04-22           NaN      consistent
#                                2022-05-10           NaN      consistent
#                                2022-08-11           NaN      consistent
#
#                                           accessible body_length_match  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17      False               NaN
#                                2022-04-17      False               NaN
#                                2022-04-17      False               NaN
#                                2022-04-17      False               NaN
#                                2022-04-18      False               NaN
# ...                                              ...               ...
# zzn.com/                       2022-04-08      False               NaN
#                                2022-04-22      False               NaN
#                                2022-04-22      False               NaN
#                                2022-05-10      False               NaN
#                                2022-08-11      False               NaN
#
#                                            body_proportion  x_null_null_flags  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17              0.0                NaN
#                                2022-04-17              0.0                NaN
#                                2022-04-17              0.0                NaN
#                                2022-04-17              0.0                NaN
#                                2022-04-18              0.0                NaN
# ...                                                    ...                ...
# zzn.com/                       2022-04-08              0.0                NaN
#                                2022-04-22              0.0                NaN
#                                2022-04-22              0.0                NaN
#                                2022-05-10              0.0                NaN
#                                2022-08-11              0.0                NaN
#
#                                           status_code_match  \
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17               NaN
#                                2022-04-17               NaN
#                                2022-04-17               NaN
#                                2022-04-17               NaN
#                                2022-04-18               NaN
# ...                                                     ...
# zzn.com/                       2022-04-08               NaN
#                                2022-04-22               NaN
#                                2022-04-22               NaN
#                                2022-05-10               NaN
#                                2022-08-11               NaN
#
#                                           dns_experiment_failure
# input                          date
# 0.39:9131/tor/server/authority 2022-04-17                    NaN
#                                2022-04-17                    NaN
#                                2022-04-17                    NaN
#                                2022-04-17                    NaN
#                                2022-04-18                    NaN
# ...                                                          ...
# zzn.com/                       2022-04-08                    NaN
#                                2022-04-22                    NaN
#                                2022-04-22                    NaN
#                                2022-05-10                    NaN
#                                2022-08-11                    NaN
#
# [14302 rows x 16 columns]

# %%
# Find sites with largest number of blocking events
topw = wmbi.groupby(level=0).size().sort_values(ascending=False)
topw
# Out:
# input
# gaytoday.com/                   244
# 206.212/tor/server/authority    237
# sputniknews.com/                181
# rt.com/                         162
# khilafah.com/                   150
#                                ...
# cia.gov/                          1
# lgbtvacationplanners.com/         1
# lgbtqnation.com/                  1
# lgbtnewsnow.org/                  1
# nytimes.com/                      1
# Length: 1194, dtype: int64

# %%
# Get data from the top blocking events
wmbi.loc[topw[topw > 10].index]
# Out:
#                          probe_asn resolver_asn  x_dns_flags  \
# input         date
# gaytoday.com/ 2022-03-02    AS5391      AS20940          NaN
#               2022-03-03    AS5391      AS13335          NaN
#               2022-03-03    AS5391      AS13335          NaN
#               2022-03-05    AS5391      AS36692          NaN
#               2022-03-08    AS5391      AS13335          NaN
# ...                            ...          ...          ...
# xvideos.com/  2022-04-04    AS5391      AS13335          NaN
#               2022-04-06    AS5391      AS20940          NaN
#               2022-04-08    AS5391      AS13335          NaN
#               2022-04-08    AS5391      AS13335          NaN
#               2022-04-22    AS5391      AS13335          NaN
#
#                           x_blocking_flags title_match  \
# input         date
# gaytoday.com/ 2022-03-02               NaN         NaN
#               2022-03-03               NaN         NaN
#               2022-03-03               NaN         NaN
#               2022-03-05               NaN         NaN
#               2022-03-08               NaN         NaN
# ...                                    ...         ...
# xvideos.com/  2022-04-04               NaN         NaN
#               2022-04-06               NaN         NaN
#               2022-04-08               NaN         NaN
#               2022-04-08               NaN         NaN
#               2022-04-22               NaN         NaN
#
#                          http_experiment_failure control_failure   blocking  \
# input         date
# gaytoday.com/ 2022-03-02                     NaN             NaN  http-diff
#               2022-03-03                     NaN             NaN  http-diff
#               2022-03-03                     NaN             NaN  http-diff
#               2022-03-05   generic_timeout_error             NaN     tcp_ip
#               2022-03-08                     NaN             NaN  http-diff
# ...                                          ...             ...        ...
# xvideos.com/  2022-04-04   generic_timeout_error             NaN     tcp_ip
#               2022-04-06   generic_timeout_error             NaN     tcp_ip
#               2022-04-08   generic_timeout_error             NaN     tcp_ip
#               2022-04-08   generic_timeout_error             NaN     tcp_ip
#               2022-04-22   generic_timeout_error             NaN     tcp_ip
#
#                          headers_match dns_consistency accessible  \
# input         date
# gaytoday.com/ 2022-03-02          True      consistent      False
#               2022-03-03          True      consistent      False
#               2022-03-03          True      consistent      False
#               2022-03-05           NaN      consistent      False
#               2022-03-08          True      consistent      False
# ...                                ...             ...        ...
# xvideos.com/  2022-04-04           NaN      consistent      False
#               2022-04-06           NaN      consistent      False
#               2022-04-08           NaN      consistent      False
#               2022-04-08           NaN      consistent      False
#               2022-04-22           NaN      consistent      False
#
#                          body_length_match  body_proportion  \
# input         date
# gaytoday.com/ 2022-03-02               NaN              0.0
#               2022-03-03               NaN              0.0
#               2022-03-03               NaN              0.0
#               2022-03-05               NaN              0.0
#               2022-03-08               NaN              0.0
# ...                                    ...              ...
# xvideos.com/  2022-04-04               NaN              0.0
#               2022-04-06               NaN              0.0
#               2022-04-08               NaN              0.0
#               2022-04-08               NaN              0.0
#               2022-04-22               NaN              0.0
#
#                           x_null_null_flags status_code_match  \
# input         date
# gaytoday.com/ 2022-03-02                NaN             False
#               2022-03-03                NaN             False
#               2022-03-03                NaN             False
#               2022-03-05                NaN               NaN
#               2022-03-08                NaN             False
# ...                                     ...               ...
# xvideos.com/  2022-04-04                NaN               NaN
#               2022-04-06                NaN               NaN
#               2022-04-08                NaN               NaN
#               2022-04-08                NaN               NaN
#               2022-04-22                NaN               NaN
#
#                          dns_experiment_failure
# input         date
# gaytoday.com/ 2022-03-02                    NaN
#               2022-03-03                    NaN
#               2022-03-03                    NaN
#               2022-03-05                    NaN
#               2022-03-08                    NaN
# ...                                         ...
# xvideos.com/  2022-04-04                    NaN
#               2022-04-06                    NaN
#               2022-04-08                    NaN
#               2022-04-08                    NaN
#               2022-04-22                    NaN
#
# [11668 rows x 16 columns]

# %%
sel = wmbi.loc[topw[topw > 10].index].loc[topw.index[10]]
ma = sel['blocking'] == 'dns'
sel[ma]
# Out:
#            probe_asn resolver_asn  x_dns_flags  x_blocking_flags title_match  \
# date
# 2022-07-16    AS5391       AS5391          NaN               NaN       False
# 2022-07-17    AS5391       AS5391          NaN               NaN       False
# 2022-07-21    AS5391       AS5391          NaN               NaN       False
# 2022-07-21    AS5391       AS5391          NaN               NaN       False
# 2022-07-22    AS5391       AS5391          NaN               NaN       False
# 2022-07-23    AS5391       AS5391          NaN               NaN       False
# 2022-07-24    AS5391       AS5391          NaN               NaN       False
# 2022-07-24    AS5391       AS5391          NaN               NaN       False
# 2022-07-24   AS62161      AS15169          NaN               NaN       False
# 2022-11-04    AS5391       AS5391          NaN               NaN       False
# 2022-11-04    AS5391       AS5391          NaN               NaN       False
# 2022-11-04    AS5391       AS5391          NaN               NaN       False
# 2022-11-04    AS5391       AS5391          NaN               NaN       False
# 2022-11-05    AS5391       AS5391          NaN               NaN       False
# 2022-11-05    AS5391       AS5391          NaN               NaN       False
# 2022-11-05    AS5391       AS5391          NaN               NaN       False
# 2022-11-05    AS5391       AS5391          NaN               NaN       False
# 2022-11-15    AS5391       AS5391          NaN               NaN       False
# 2022-11-15    AS5391       AS5391          NaN               NaN       False
# 2022-11-15    AS5391       AS5391          NaN               NaN       False
# 2022-11-15    AS5391       AS5391          NaN               NaN       False
# 2022-11-15    AS5391      AS13335          NaN               NaN       False
# 2022-11-15    AS5391      AS13335          NaN               NaN       False
# 2022-12-12    AS5391       AS5391          NaN               NaN       False
# 2022-12-20   AS12417      AS12417          NaN               NaN       False
# 2022-12-20   AS12417      AS12417          NaN               NaN       False
#
#            http_experiment_failure control_failure blocking headers_match  \
# date
# 2022-07-16                     NaN             NaN      dns          True
# 2022-07-17                     NaN             NaN      dns          True
# 2022-07-21                     NaN             NaN      dns          True
# 2022-07-21                     NaN             NaN      dns          True
# 2022-07-22                     NaN             NaN      dns          True
# 2022-07-23                     NaN             NaN      dns          True
# 2022-07-24                     NaN             NaN      dns          True
# 2022-07-24                     NaN             NaN      dns          True
# 2022-07-24                     NaN             NaN      dns          True
# 2022-11-04                     NaN             NaN      dns          True
# 2022-11-04                     NaN             NaN      dns          True
# 2022-11-04                     NaN             NaN      dns          True
# 2022-11-04                     NaN             NaN      dns          True
# 2022-11-05                     NaN             NaN      dns          True
# 2022-11-05                     NaN             NaN      dns          True
# 2022-11-05                     NaN             NaN      dns          True
# 2022-11-05                     NaN             NaN      dns          True
# 2022-11-15                     NaN             NaN      dns          True
# 2022-11-15                     NaN             NaN      dns          True
# 2022-11-15                     NaN             NaN      dns          True
# 2022-11-15                     NaN             NaN      dns          True
# 2022-11-15                     NaN             NaN      dns          True
# 2022-11-15                     NaN             NaN      dns          True
# 2022-12-12                     NaN             NaN      dns          True
# 2022-12-20                     NaN             NaN      dns          True
# 2022-12-20                     NaN             NaN      dns          True
#
#            dns_consistency accessible body_length_match  body_proportion  \
# date
# 2022-07-16    inconsistent      False             False         0.031078
# 2022-07-17    inconsistent      False             False         0.031195
# 2022-07-21    inconsistent      False             False         0.031195
# 2022-07-21    inconsistent      False             False         0.031195
# 2022-07-22    inconsistent      False             False         0.030962
# 2022-07-23    inconsistent      False             False         0.031078
# 2022-07-24    inconsistent      False             False         0.031199
# 2022-07-24    inconsistent      False             False         0.031082
# 2022-07-24    inconsistent      False             False         0.031199
# 2022-11-04    inconsistent      False             False         0.031078
# 2022-11-04    inconsistent      False             False         0.031078
# 2022-11-04    inconsistent      False             False         0.031082
# 2022-11-04    inconsistent      False             False         0.031078
# 2022-11-05    inconsistent      False             False         0.031078
# 2022-11-05    inconsistent      False             False         0.031078
# 2022-11-05    inconsistent      False             False         0.031078
# 2022-11-05    inconsistent      False             False         0.031078
# 2022-11-15    inconsistent      False             False         0.031192
# 2022-11-15    inconsistent      False             False         0.031195
# 2022-11-15    inconsistent      False             False         0.031195
# 2022-11-15    inconsistent      False             False         0.031206
# 2022-11-15    inconsistent      False             False         0.031086
# 2022-11-15    inconsistent      False             False         0.031086
# 2022-12-12    inconsistent      False             False         0.031192
# 2022-12-20    inconsistent      False             False         0.031206
# 2022-12-20    inconsistent      False             False         0.031199
#
#             x_null_null_flags status_code_match dns_experiment_failure
# date
# 2022-07-16                NaN             False                    NaN
# 2022-07-17                NaN             False                    NaN
# 2022-07-21                NaN             False                    NaN
# 2022-07-21                NaN             False                    NaN
# 2022-07-22                NaN             False                    NaN
# 2022-07-23                NaN             False                    NaN
# 2022-07-24                NaN             False                    NaN
# 2022-07-24                NaN             False                    NaN
# 2022-07-24                NaN             False                    NaN
# 2022-11-04                NaN             False                    NaN
# 2022-11-04                NaN             False                    NaN
# 2022-11-04                NaN             False                    NaN
# 2022-11-04                NaN             False                    NaN
# 2022-11-05                NaN             False                    NaN
# 2022-11-05                NaN             False                    NaN
# 2022-11-05                NaN             False                    NaN
# 2022-11-05                NaN             False                    NaN
# 2022-11-15                NaN             False                    NaN
# 2022-11-15                NaN             False                    NaN
# 2022-11-15                NaN             False                    NaN
# 2022-11-15                NaN             False                    NaN
# 2022-11-15                NaN             False                    NaN
# 2022-11-15                NaN             False                    NaN
# 2022-12-12                NaN             False                    NaN
# 2022-12-20                NaN             False                    NaN
# 2022-12-20                NaN             False                    NaN

# %%
web_connectivity.loc[web_connectivity['input'] == topw.index[0]]
# Out:
#            probe_asn resolver_asn  x_dns_flags  x_blocking_flags title_match  \
# date
# 2022-03-02    AS5391      AS20940          NaN               NaN         NaN
# 2022-03-03    AS5391      AS13335          NaN               NaN         NaN
# 2022-03-03    AS5391      AS13335          NaN               NaN         NaN
# 2022-03-04    AS5391      AS13335          NaN               NaN         NaN
# 2022-03-05    AS5391      AS36692          NaN               NaN         NaN
# ...              ...          ...          ...               ...         ...
# 2022-12-18   AS12417      AS12417          NaN               NaN         NaN
# 2022-12-20   AS12417      AS12417          NaN               NaN         NaN
# 2022-12-21    AS5391       AS5391          NaN               NaN         NaN
# 2022-12-21    AS5391      AS15169          NaN               NaN         NaN
# 2022-12-23    AS5391       AS5391          NaN               NaN         NaN
#
#            http_experiment_failure control_failure   blocking headers_match  \
# date
# 2022-03-02                     NaN             NaN  http-diff          True
# 2022-03-03                     NaN             NaN  http-diff          True
# 2022-03-03                     NaN             NaN  http-diff          True
# 2022-03-04                     NaN             NaN      False          True
# 2022-03-05   generic_timeout_error             NaN     tcp_ip           NaN
# ...                            ...             ...        ...           ...
# 2022-12-18                     NaN             NaN      False          True
# 2022-12-20                     NaN             NaN  http-diff          True
# 2022-12-21                     NaN             NaN  http-diff          True
# 2022-12-21                     NaN             NaN  http-diff          True
# 2022-12-23                     NaN             NaN  http-diff          True
#
#            dns_consistency          input accessible body_length_match  \
# date
# 2022-03-02      consistent  gaytoday.com/      False               NaN
# 2022-03-03      consistent  gaytoday.com/      False               NaN
# 2022-03-03      consistent  gaytoday.com/      False               NaN
# 2022-03-04      consistent  gaytoday.com/       True               NaN
# 2022-03-05      consistent  gaytoday.com/      False               NaN
# ...                    ...            ...        ...               ...
# 2022-12-18      consistent  gaytoday.com/       True               NaN
# 2022-12-20      consistent  gaytoday.com/      False               NaN
# 2022-12-21      consistent  gaytoday.com/      False               NaN
# 2022-12-21      consistent  gaytoday.com/      False               NaN
# 2022-12-23      consistent  gaytoday.com/      False               NaN
#
#             body_proportion  x_null_null_flags status_code_match  \
# date
# 2022-03-02              0.0                NaN             False
# 2022-03-03              0.0                NaN             False
# 2022-03-03              0.0                NaN             False
# 2022-03-04              0.0                NaN              True
# 2022-03-05              0.0                NaN               NaN
# ...                     ...                ...               ...
# 2022-12-18              0.0                NaN              True
# 2022-12-20              0.0                NaN             False
# 2022-12-21              0.0                NaN             False
# 2022-12-21              0.0                NaN             False
# 2022-12-23              0.0                NaN             False
#
#            dns_experiment_failure
# date
# 2022-03-02                    NaN
# 2022-03-03                    NaN
# 2022-03-03                    NaN
# 2022-03-04                    NaN
# 2022-03-05                    NaN
# ...                           ...
# 2022-12-18                    NaN
# 2022-12-20                    NaN
# 2022-12-21                    NaN
# 2022-12-21                    NaN
# 2022-12-23                    NaN
#
# [270 rows x 17 columns]

# %%
# Group all events by input calculate totals
dns_grouped = dns_events.groupby('input').size() # sort_values(ascending=False)
httpdiff_grouped = httpdiff_events.groupby('input').size()
httpfail_grouped = httpfail_events.groupby('input').size()
tcp_grouped = tcp_events.groupby('input').size()
totals_grouped = web_connectivity.groupby('input').size()

# %%
noblock_events = web_connectivity[(web_connectivity['blocking'] == 'False') | (web_connectivity['blocking'].isnull())]
noblock_grouped = noblock_events.groupby('input').size()

# %%
# Calculate fraction of events blocked per input
frac_dns_grouped = (dns_grouped / totals_grouped).dropna().sort_values(ascending=False)
frac_httpdiff_grouped = (httpdiff_grouped / totals_grouped).dropna().sort_values(ascending=False)
frac_httpfail_grouped = (httpfail_grouped / totals_grouped).dropna().sort_values(ascending=False)
frac_tcp_grouped = (tcp_grouped / totals_grouped).dropna().sort_values(ascending=False)

# %%
# Get all events grouped by the type of blocking event
all_grouped = pd.DataFrame({'dns': frac_dns_grouped, 'httpdiff': frac_httpdiff_grouped, 'httpfail': frac_httpfail_grouped, 'tcp': frac_tcp_grouped}).fillna(0)
all_grouped
# Out:
#                                      dns  httpdiff  httpfail       tcp
# input
# 0.39:9131/tor/server/authority  0.000000  0.000000  0.061008  0.180371
# 1.1/dns-query                   0.000000  0.000000  0.000000  0.015152
# 150m.com/                       0.027933  0.000000  0.000000  0.368715
# 163.com/                        0.000000  0.000000  0.000000  0.136842
# 164.118/tor/server/authority    0.000000  0.033708  0.000000  0.033708
# ...                                  ...       ...       ...       ...
# zoho.com/                       0.005988  0.000000  0.000000  0.000000
# zone-h.org/                     0.000000  0.000000  0.000000  0.061069
# zoom.us/zoom.ico                0.008000  0.000000  0.000000  0.000000
# zoomshare.com/                  0.003623  0.000000  0.000000  0.000000
# zzn.com/                        0.000000  0.000000  0.000000  0.070796
#
# [1194 rows x 4 columns]

# %%
# Extract the top N sites
nn = 100
top_n_idx = all_grouped.sum(axis=1).sort_values(ascending=False)[0:nn].index
top_n = all_grouped.loc[top_n_idx]
top_n
# Out:
#                           dns  httpdiff  httpfail       tcp
# input
# internetarchive.org  1.000000  0.000000  0.000000  0.000000
# freerk.com/          0.000000  0.795455  0.000000  0.204545
# xfocus.org/          0.000000  0.017857  0.017857  0.964286
# williamhill.com/     1.000000  0.000000  0.000000  0.000000
# delicious.com/       1.000000  0.000000  0.000000  0.000000
# ...                       ...       ...       ...       ...
# hackers.com/         0.000000  0.000000  0.000000  0.137931
# uptodown.com/        0.000000  0.000000  0.000000  0.137931
# about.com/           0.000000  0.000000  0.000000  0.137500
# 163.com/             0.000000  0.000000  0.000000  0.136842
# itsyoursexlife.com/  0.003226  0.000000  0.000000  0.132258
#
# [100 rows x 4 columns]

# %%
# Calculate cumulative values
c_top_n = top_n.cumsum(axis=1)

# %%
# Plot 
plt.rcParams['figure.figsize'] = [5, 20]
plt.barh(top_n.index[::-1].str.slice(0,60), top_n['dns'].iloc[::-1], label='dns', alpha=0.8)
plt.barh(top_n.index[::-1].str.slice(0,60), top_n['httpdiff'].iloc[::-1], left=c_top_n.iloc[::-1,0], label='httpdiff', alpha=0.8)
plt.barh(top_n.index[::-1].str.slice(0,60), top_n['httpfail'].iloc[::-1], left=c_top_n.iloc[::-1,1], label='httpfail', alpha=0.8)
plt.barh(top_n.index[::-1].str.slice(0,60), top_n['tcp'].iloc[::-1], left=c_top_n.iloc[::-1,2], label='tcp', alpha=0.8)
plt.margins(y=0)
plt.legend()
plt.grid()
plt.title(f'Top {nn} Blocked Sites')
plt.xlabel('Fraction of events')
# Out:
# Text(0.5, 0, 'Fraction of events')
